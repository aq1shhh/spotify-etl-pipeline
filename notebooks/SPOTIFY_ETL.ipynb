# %%
pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 279.8/279.8 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import spotipy

# %%
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager=SpotifyClientCredentials(client_id="abc123def456",client_secret="")

# %%
sp=spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
top_100_global_songs_link=("https://open.spotify.com/playlist/5dnSFdz51E2Qouk7iFnwbl?si=hCN7h0B7RCaqN1xtktSdkw")

# %%
playlist_uri=top_100_global_songs_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_tracks(top_100_global_songs_link, limit=100)

# %%
data['items']
# Out:
# [{'added_at': '2025-08-10T10:13:56Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/suo2sbl91eeth3elwrfuq7qwn'},
#    'href': 'https://api.spotify.com/v1/users/suo2sbl91eeth3elwrfuq7qwn',
#    'id': 'suo2sbl91eeth3elwrfuq7qwn',
#    'type': 'user',
#    'uri': 'spotify:user:suo2sbl91eeth3elwrfuq7qwn'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'preview_url': None,
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
# ...

# %%
len(data['items'])
# Out:
# 100

# %%
data['items'][0]['track']['album']['id']
# Out:
# '14JkAa6IiFaOh5s0nMyMU9'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'KPop Demon Hunters (Soundtrack from the Netflix Film)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2025-06-20'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 12

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/14JkAa6IiFaOh5s0nMyMU9'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/14JkAa6IiFaOh5s0nMyMU9'

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']['spotify']
    album_element={"album_id":album_id,"album_name":album_name,"release_date":album_release_date,"total_tracks":album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '14JkAa6IiFaOh5s0nMyMU9',
#   'album_name': 'KPop Demon Hunters (Soundtrack from the Netflix Film)',
#   'release_date': '2025-06-20',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/14JkAa6IiFaOh5s0nMyMU9'},
#  {'album_id': '6ZXIXOT3F3ixjH66eqJl0S',
#   'album_name': 'SWAG',
#   'release_date': '2025-07-11',
#   'total_tracks': 21,
#   'url': 'https://open.spotify.com/album/6ZXIXOT3F3ixjH66eqJl0S'},
#  {'album_id': '20ELrZscOxiFwfygQ8QIek',
#   'album_name': 'Campfire Folk',
#   'release_date': '2025-02-22',
#   'total_tracks': 37,
#   'url': 'https://open.spotify.com/album/20ELrZscOxiFwfygQ8QIek'},
#  {'album_id': '14JkAa6IiFaOh5s0nMyMU9',
#   'album_name': 'KPop Demon Hunters (Soundtrack from the Netflix Film)',
#   'release_date': '2025-06-20',
#   'total_tracks': 12,
#   'url': 'https://open.spotify.com/album/14JkAa6IiFaOh5s0nMyMU9'},
#  {'album_id': '6ZXIXOT3F3ixjH66eqJl0S',
#   'album_name': 'SWAG',
#   'release_date': '2025-07-11',
# ...

# %%
data['items'][1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1uNFoZAHBGtllmzznpCI3s'},
#   'href': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s',
#   'id': '1uNFoZAHBGtllmzznpCI3s',
#   'name': 'Justin Bieber',
#   'type': 'artist',
#   'uri': 'spotify:artist:1uNFoZAHBGtllmzznpCI3s'}]

# %%
artist_list=[]
for row in data['items']:
  for key,value in row.items():
    if key=="track":
      for artist in value['artists']:
        artist_dict={"artist_id":artist['id'],"artist_name":artist['name'],"external_url":artist['href']}
        artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '2yNNYQBChuox9A5Ka93BIn',
#   'artist_name': 'HUNTR/X',
#   'external_url': 'https://api.spotify.com/v1/artists/2yNNYQBChuox9A5Ka93BIn'},
#  {'artist_id': '0RMJOzHDhAKY1o2j0W0vxY',
#   'artist_name': 'EJAE',
#   'external_url': 'https://api.spotify.com/v1/artists/0RMJOzHDhAKY1o2j0W0vxY'},
#  {'artist_id': '0Wwji82sLA0Hcvtuak3omb',
#   'artist_name': 'AUDREY NUNA',
#   'external_url': 'https://api.spotify.com/v1/artists/0Wwji82sLA0Hcvtuak3omb'},
#  {'artist_id': '6U1dV7aL68N7Gb0Naq34V5',
#   'artist_name': 'REI AMI',
#   'external_url': 'https://api.spotify.com/v1/artists/6U1dV7aL68N7Gb0Naq34V5'},
#  {'artist_id': '7mW7Tv7NvywKKXqafZo0Lc',
#   'artist_name': 'KPop Demon Hunters Cast',
#   'external_url': 'https://api.spotify.com/v1/artists/7mW7Tv7NvywKKXqafZo0Lc'},
#  {'artist_id': '1uNFoZAHBGtllmzznpCI3s',
#   'artist_name': 'Justin Bieber',
#   'external_url': 'https://api.spotify.com/v1/artists/1uNFoZAHBGtllmzznpCI3s'},
#  {'artist_id': '0fTSzq9jAh4c36UVb4V7CB',
# ...

# %%
song_list=[]
for row in data['items']:
  song_id=row['track']['id']
  song_name=row['track']['name']
  song_duration=row['track']['duration_ms']
  song_url=row['track']['external_urls']['spotify']
  song_popularity=row['track']['popularity']
  song_added=row['added_at']
  album_id=row['track']['album']['id']
  artist_id=row['track']['album']['artists'][0]['id']
  song_element={"song_id":song_id,"song_name":song_name,"duration_ms":song_duration,"url":song_url,"popularity":song_popularity,"song_added":song_added,"album_id":album_id,"artist_id":artist_id}
  song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '1CPZ5BxNNd0n0nF4Orb9JS',
#   'song_name': 'Golden',
#   'duration_ms': 194607,
#   'url': 'https://open.spotify.com/track/1CPZ5BxNNd0n0nF4Orb9JS',
#   'popularity': 100,
#   'song_added': '2025-08-10T10:13:56Z',
#   'album_id': '14JkAa6IiFaOh5s0nMyMU9',
#   'artist_id': '7mW7Tv7NvywKKXqafZo0Lc'},
#  {'song_id': '7rcbwjIaZ5jEgyFk35Bqfj',
#   'song_name': 'DAISIES',
#   'duration_ms': 176453,
#   'url': 'https://open.spotify.com/track/7rcbwjIaZ5jEgyFk35Bqfj',
#   'popularity': 78,
#   'song_added': '2025-08-10T10:13:56Z',
#   'album_id': '6ZXIXOT3F3ixjH66eqJl0S',
#   'artist_id': '1uNFoZAHBGtllmzznpCI3s'},
#  {'song_id': '0ml63fN6DFNvKLH6hEU1Mu',
#   'song_name': 'Ordinary',
#   'duration_ms': 186964,
#   'url': 'https://open.spotify.com/track/0ml63fN6DFNvKLH6hEU1Mu',
#   'popularity': 37,
#   'song_added': '2025-08-10T10:13:56Z',
#   'album_id': '20ELrZscOxiFwfygQ8QIek',
#   'artist_id': '0LyfQWJT6nXafLPZqxe9Of'},
#  {'song_id': '02sy7FAs8dkDNYsHp4Ul3f',
# ...

# %%
album_df=pd.DataFrame.from_dict(album_list)

# %%
album_df
# Out:
#                   album_id                                         album_name  \
# 0   14JkAa6IiFaOh5s0nMyMU9  KPop Demon Hunters (Soundtrack from the Netfli...
# 1   6ZXIXOT3F3ixjH66eqJl0S                                               SWAG
# 2   20ELrZscOxiFwfygQ8QIek                                      Campfire Folk
# 3   14JkAa6IiFaOh5s0nMyMU9  KPop Demon Hunters (Soundtrack from the Netfli...
# 4   6ZXIXOT3F3ixjH66eqJl0S                                               SWAG
# ..                     ...                                                ...
# 95  7lxHnls3yQNl8B9bILmHj7                                          Traveller
# 96  5IZ8sY5FjtL9hloXpv0XbD                                    I’m The Problem
# 97  4CZBLiXAPe237EfXNZ35Gl                                 Redención (Deluxe)
# 98  1VoARePwuGf1zb7iYKuOqd                                               クスシキ
# 99  6S3xkUk67SSNzWhGDoKyt5                                Inferno & More Hits
#
#    release_date  total_tracks  \
# ...

# %%
artist_df=pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head()
# Out:
#                 artist_id              artist_name  \
# 0  2yNNYQBChuox9A5Ka93BIn                  HUNTR/X
# 1  0RMJOzHDhAKY1o2j0W0vxY                     EJAE
# 2  0Wwji82sLA0Hcvtuak3omb              AUDREY NUNA
# 3  6U1dV7aL68N7Gb0Naq34V5                  REI AMI
# 4  7mW7Tv7NvywKKXqafZo0Lc  KPop Demon Hunters Cast
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/2yNNYQBChuo...
# 1  https://api.spotify.com/v1/artists/0RMJOzHDhAK...
# 2  https://api.spotify.com/v1/artists/0Wwji82sLA0...
# 3  https://api.spotify.com/v1/artists/6U1dV7aL68N...
# 4  https://api.spotify.com/v1/artists/7mW7Tv7Nvyw...

# %%
songs_df=pd.DataFrame.from_dict(song_list)

# %%
songs_df.head()
# Out:
#                   song_id song_name  duration_ms  \
# 0  1CPZ5BxNNd0n0nF4Orb9JS    Golden       194607
# 1  7rcbwjIaZ5jEgyFk35Bqfj   DAISIES       176453
# 2  0ml63fN6DFNvKLH6hEU1Mu  Ordinary       186964
# 3  02sy7FAs8dkDNYsHp4Ul3f  Soda Pop       150686
# 4  6Z3iROBd8ULQRJymXD8gdg     YUKON       163866
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/1CPZ5BxNNd0n0nF...         100
# 1  https://open.spotify.com/track/7rcbwjIaZ5jEgyF...          78
# 2  https://open.spotify.com/track/0ml63fN6DFNvKLH...          37
# 3  https://open.spotify.com/track/02sy7FAs8dkDNYs...          96
# 4  https://open.spotify.com/track/6Z3iROBd8ULQRJy...          63
#
#              song_added                album_id               artist_id
# 0  2025-08-10T10:13:56Z  14JkAa6IiFaOh5s0nMyMU9  7mW7Tv7NvywKKXqafZo0Lc
# 1  2025-08-10T10:13:56Z  6ZXIXOT3F3ixjH66eqJl0S  1uNFoZAHBGtllmzznpCI3s
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   album_name    100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df=album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df=artist_df.drop_duplicates(subset=['artist_id'])

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      61 non-null     object
#  1   album_name    61 non-null     object
#  2   release_date  61 non-null     object
#  3   total_tracks  61 non-null     int64
#  4   url           61 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.9+ KB
